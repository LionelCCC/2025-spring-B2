# %% [markdown]
# # Week 7 - Milestone One week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone One is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Below are the graphs from last week's weekly graph question.  Suppose you wanted to cause the viewer to examine the last three months of data first.  How could you use preattentive attributes to do that?  Suggest several possibilities.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# /tmp/ipykernel_2798/2149468501.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series = 100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %%
numdates = 12
np.random.seed(0)
time_series_nitrate = 100 * (np.random.normal(size=numdates) / 5 + np.arange(numdates) / 16)
np.random.seed(1)
time_series_phosphate = 100 * (1 - (np.random.normal(size=numdates) / 8 + np.arange(numdates) / 16))

datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')


highlight_dates = datearray[-3:]
highlight_nitrate = time_series_nitrate[-3:]
highlight_phosphate = time_series_phosphate[-3:]
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 1, figsize=(8, 10))


ax = axes[0]
ax.plot(datearray, time_series_nitrate, color='gray', linestyle='dashed', alpha=0.5, label="Previous Data")
ax.plot(highlight_dates, highlight_nitrate, color='red', linewidth=2.5, marker='o', label="Highlighted Data")
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
ax.legend()
ax.set_title("Nitrate Levels Over Time")


ax = axes[1]
ax.plot(datearray, time_series_phosphate, color='gray', linestyle='dashed', alpha=0.5, label="Previous Data")
ax.plot(highlight_dates, highlight_phosphate, color='blue', linewidth=2.5, marker='o', label="Highlighted Data")
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
ax.legend()
ax.set_title("Phosphate Levels Over Time")


plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2798/4112619771.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone One rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 99-119 of the Storytelling With Data book as best you can. (The first half of chapter four). You do not have to get the exact data values right, just the overall look and feel.

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
received = [160, 184, 241, 149, 180, 161, 132, 202, 160, 139, 149, 177]
processed = [160, 184, 247, 148, 181, 150, 123, 156, 126, 104, 124, 140]

highlight_start = 7  
highlight_end = 12  

plt.figure(figsize=(6, 4), dpi=100)
plt.plot(months, received, color='gray', linestyle="-", linewidth=2, alpha=0.5, marker='o', label="Received")
plt.plot(months, processed, color='navy', linestyle="-", linewidth=2, alpha=0.5, marker='o', label="Processed")

plt.plot(months[highlight_start:highlight_end], received[highlight_start:highlight_end], 
         color='black', linestyle="-", linewidth=2.5, marker='o')
plt.plot(months[highlight_start:highlight_end], processed[highlight_start:highlight_end], 
         color='darkblue', linestyle="-", linewidth=2.5, marker='o')

for i in range(highlight_start, highlight_end):
    plt.text(months[i], received[i], str(received[i]), fontsize=10, color='black', fontweight='bold')
    plt.text(months[i], processed[i], str(processed[i]), fontsize=10, color='darkblue', fontweight='bold')

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylabel("")
plt.xlabel("")
plt.legend(loc="upper right", fontsize=10)
plt.grid(False)
plt.tight_layout()
plt.show()
